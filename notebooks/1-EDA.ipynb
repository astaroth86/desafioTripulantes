# %%
![imagen](../EDA-DONANTES/MeraParivar.jpeg)
# Out:
# "[imagen]" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %% [markdown]
# #### LIBRERIAS

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import calendar

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# #### IMPORTACIÓN DEL DATASET

# %%
mp_donantes = pd.read_csv("../data/datos_donantes.csv")

# %% [markdown]
# #### INFORMACIÓN PRELIMINAR

# %%
mp_donantes.shape
# Out:
# (3934, 13)

# %%
mp_donantes.head()
# Out:
#               name                      email        date  is_partner  \
# 0       Tara Young       tara.young@gmail.com  2017-10-22           1
# 1    Bobby Acevedo    bobby.acevedo@gmail.com  2019-02-18           0
# 2      James Payne      james.payne@gmail.com  2013-03-06           0
# 3   Heather Mooney   heather.mooney@gmail.com  2013-06-02           1
# 4  Joseph Anderson  joseph.anderson@gmail.com  2024-01-21           1
#
#       company role_company  donation_frecuency  suscription_status  \
# 0        Nike          CTO                   1                   1
# 1         NaN          NaN                   0                   0
# 2         NaN          NaN                   0                   0
# 3    Jonhsons     Employee                   0                   1
# 4  The Oberoi     Employee                   1                   1
#
#    donation_type   amount  method_pay donation_date
# 0              4     0.00           1    2021-11-14
# 1              1  1355.38           3    2022-05-01
# 2              1  8132.27           3    2014-10-18
# 3              2     0.00           2    2018-06-11
# 4              2     0.00           2    2024-01-30

# %%
mp_donantes.tail()
# Out:
#                 name                     email        date  is_partner  \
# 3929  Thomas Edwards  thomas.edwards@gmail.com  2021-06-06           0
# 3930  Thomas Edwards  thomas.edwards@gmail.com  2021-06-06           0
# 3931  Thomas Edwards  thomas.edwards@gmail.com  2021-06-06           0
# 3932  Thomas Edwards  thomas.edwards@gmail.com  2021-06-06           0
# 3933  Thomas Edwards  thomas.edwards@gmail.com  2021-06-06           0
#
#      company role_company  donation_frecuency  suscription_status  \
# 3929     NaN          NaN                   1                   1
# 3930     NaN          NaN                   1                   1
# 3931     NaN          NaN                   1                   1
# 3932     NaN          NaN                   1                   1
# 3933     NaN          NaN                   1                   1
#
#       donation_type   amount  method_pay donation_date
# 3929              1  3162.55           1    2022-09-06
# 3930              1  3162.55           1    2022-10-06
# 3931              1  3162.55           1    2022-11-06
# 3932              1  3162.55           1    2022-12-06
# 3933              1  3162.55           1    2023-01-06

# %%
mp_donantes.sample(5)
# Out:
#                        name                             email        date  \
# 1322  Mrs. Margaret Bullock  mrs. margaret bullock.@gmail.com  2017-08-07
# 1869          Samantha Cruz           samantha.cruz@gmail.com  2016-11-14
# 3760       Kimberly Ellison        kimberly.ellison@gmail.com  2007-02-11
# 3398          Traci Sanchez           traci.sanchez@gmail.com  2009-02-24
# 3255          Jenny Wilkins           jenny.wilkins@gmail.com  2018-02-04
#
#       is_partner company role_company  donation_frecuency  suscription_status  \
# 1322           0     NaN          NaN                   1                   1
# 1869           0     NaN          NaN                   1                   1
# 3760           0     NaN          NaN                   1                   1
# 3398           0     NaN          NaN                   1                   1
# 3255           0     NaN          NaN                   1                   1
#
#       donation_type   amount  method_pay donation_date
# 1322              1  1807.17           3    2017-11-07
# 1869              1   903.59           2    2018-01-14
# 3760              1   903.59           1    2007-09-11
# 3398              1   451.79           2    2010-07-24
# 3255              1  3162.55           1    2019-01-04

# %%
mp_donantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3934 entries, 0 to 3933
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                3934 non-null   object
#  1   email               3934 non-null   object
#  2   date                3934 non-null   object
#  3   is_partner          3934 non-null   int64
#  4   company             497 non-null    object
#  5   role_company        497 non-null    object
#  6   donation_frecuency  3934 non-null   int64
#  7   suscription_status  3934 non-null   int64
#  8   donation_type       3934 non-null   int64
#  9   amount              3934 non-null   float64
#  10  method_pay          3934 non-null   int64
#  11  donation_date       3934 non-null   object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 368.9+ KB

# %%
mp_donantes.describe(include='all')
# Out:
#                    name                      email        date   is_partner  \
# count              3934                       3934        3934  3934.000000
# unique              994                        994         496          NaN
# top     Christy Johnson  christy.johnson@gmail.com  2023-10-29          NaN
# freq                 24                         24          39          NaN
# mean                NaN                        NaN         NaN     0.126335
# std                 NaN                        NaN         NaN     0.332268
# min                 NaN                        NaN         NaN     0.000000
# 25%                 NaN                        NaN         NaN     0.000000
# 50%                 NaN                        NaN         NaN     0.000000
# 75%                 NaN                        NaN         NaN     0.000000
# max                 NaN                        NaN         NaN     1.000000
#
#            company role_company  donation_frecuency  suscription_status  \
# count          497          497         3934.000000         3934.000000
# unique          16            3                 NaN                 NaN
# top     The Oberoi     Employee                 NaN                 NaN
# freq            39          175                 NaN                 NaN
# mean           NaN          NaN            0.873157            0.936197
# std            NaN          NaN            0.332839            0.244432
# min            NaN          NaN            0.000000            0.000000
# 25%            NaN          NaN            1.000000            1.000000
# 50%            NaN          NaN            1.000000            1.000000
# 75%            NaN          NaN            1.000000            1.000000
# max            NaN          NaN            1.000000            1.000000
#
#         donation_type       amount   method_pay donation_date
# count     3934.000000  3934.000000  3934.000000          3934
# unique            NaN          NaN          NaN          2995
# top               NaN          NaN          NaN    2024-02-14
# freq              NaN          NaN          NaN             6
# mean         1.174631  3005.890974     1.918149           NaN
# std          0.604885  2954.647326     0.809875           NaN
# min          1.000000     0.000000     1.000000           NaN
# 25%          1.000000   451.790000     1.000000           NaN
# 50%          1.000000  1807.170000     2.000000           NaN
# 75%          1.000000  4517.930000     3.000000           NaN
# max          4.000000  9035.860000     3.000000           NaN

# %% [markdown]
# Algunas deducciones que se pueden hacer en base a los datos estadísticos son las siguientes:
#
# - Todas las variables, excepto 'company' y 'role_company' tienen 3934 observaciones que es la cantidad total de filas del dataset. Company y role_company tienen 497 observaciones, que es apenas un 12.67% del total, es decir, el resto son donaciones de particulares.
#
# - 'Christy Johnson' es quien mas donaciones realizó, '2023-10-29' es la fecha en la que se registraron mayor cantidad de donantes, 'The Oberoi' es la empresa más frecuente, 2024-02-14 fue el día que mayor cantidad de donaciones se recibieron.
#
# - En cuanto a la variable 'donation_frecuency' se puede ver que la mediana de 1 muestra que la mayoría de las observaciones tienen una frecuencia de donación alta.
#
# - La desviación estándar de 'amount' (target del modelo) es alta, lo que indica una gran variabilidad en los montos de donación.

# %%
# DataFrame numérico

mp_donantes_numerico = mp_donantes.drop(['name',	'email',	'date', 'company',	
                                         'role_company', 'donation_date'], axis=1)
mp_donantes_numerico
# Out:
#       is_partner  donation_frecuency  suscription_status  donation_type  \
# 0              1                   1                   1              4
# 1              0                   0                   0              1
# 2              0                   0                   0              1
# 3              1                   0                   1              2
# 4              1                   1                   1              2
# ...          ...                 ...                 ...            ...
# 3929           0                   1                   1              1
# 3930           0                   1                   1              1
# 3931           0                   1                   1              1
# 3932           0                   1                   1              1
# 3933           0                   1                   1              1
#
#        amount  method_pay
# 0        0.00           1
# 1     1355.38           3
# 2     8132.27           3
# 3        0.00           2
# 4        0.00           2
# ...       ...         ...
# 3929  3162.55           1
# 3930  3162.55           1
# 3931  3162.55           1
# 3932  3162.55           1
# 3933  3162.55           1
#
# [3934 rows x 6 columns]

# %%
# Análisis de la cardinalidad

for i in mp_donantes.select_dtypes(include=object):
    print(f"La cardinalidad de la variable {i} es {(mp_donantes[i].nunique()/mp_donantes.shape[0])*100:.2f}%")
# Out:
# La cardinalidad de la variable name es 25.27%
# La cardinalidad de la variable email es 25.27%
# La cardinalidad de la variable date es 12.61%
# La cardinalidad de la variable company es 0.43%
# La cardinalidad de la variable role_company es 0.10%

# %% [markdown]
# Las columnas 'name' y 'email' tienen una alta cardinalidad, alrededor del 25.27%. Esto sugiere que hay una gran variedad de nombres y direcciones de correo electrónico únicos en el conjunto de datos.

# %% [markdown]
# #### LIMPIEZA DEL DATAFRAME

# %%
mp_donantes.duplicated().sum()
# Out:
# 0

# %%
mp_donantes_numerico_ = mp_donantes.select_dtypes(include=['int64', 'float64']).notnull()

n_filas = mp_donantes.shape[0]

for col in mp_donantes_numerico_:
    mp_donantes[col] = pd.to_numeric(mp_donantes[col], errors='coerce') # Convierte los datos a tipo numérico

    Q1 = mp_donantes[col].quantile(0.25)
    Q3 = mp_donantes[col].quantile(0.75)
    IQR = Q3 - Q1

    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR

    outliers = mp_donantes[(mp_donantes[col] < limite_inferior) | (mp_donantes[col] > limite_superior)]

    n_outliers = len(outliers)
    porcentaje = (n_outliers / n_filas) * 100

    print(f"La columna {col} tiene {n_outliers} outliers, que representan el {porcentaje:.2f}% del total de filas.")

mp_donantes[mp_donantes_numerico_].boxplot(rot=90, figsize=(8, 4))
plt.title("Boxplot de outliers")
plt.show()
# Out:
# La columna is_partner tiene 497 outliers, que representan el 12.63% del total de filas.
# La columna donation_frecuency tiene 499 outliers, que representan el 12.68% del total de filas.
# La columna suscription_status tiene 251 outliers, que representan el 6.38% del total de filas.
# La columna donation_type tiene 355 outliers, que representan el 9.02% del total de filas.
# La columna amount tiene 0 outliers, que representan el 0.00% del total de filas.
# La columna method_pay tiene 0 outliers, que representan el 0.00% del total de filas.

# %% [markdown]
# Para no eliminar datos en las columnas 'is_partner',	'donation_frecuency',	'suscription_status' y	'donation_type' se trataría a los mismos con transformación logarítmica previo al escalado de los datos.

# %%
# Se efectúa una sustitución de los valores NaN por "particular" en las variables 'company' y 'role_company'.

mp_donantes.fillna({'company': 'Particular', 'role_company': 'Particular'}, inplace=True)
# Out:
#                  name                      email        date  is_partner  \
# 0          Tara Young       tara.young@gmail.com  2017-10-22           1
# 1       Bobby Acevedo    bobby.acevedo@gmail.com  2019-02-18           0
# 2         James Payne      james.payne@gmail.com  2013-03-06           0
# 3      Heather Mooney   heather.mooney@gmail.com  2013-06-02           1
# 4     Joseph Anderson  joseph.anderson@gmail.com  2024-01-21           1
# ...               ...                        ...         ...         ...
# 3929   Thomas Edwards   thomas.edwards@gmail.com  2021-06-06           0
# 3930   Thomas Edwards   thomas.edwards@gmail.com  2021-06-06           0
# 3931   Thomas Edwards   thomas.edwards@gmail.com  2021-06-06           0
# 3932   Thomas Edwards   thomas.edwards@gmail.com  2021-06-06           0
# 3933   Thomas Edwards   thomas.edwards@gmail.com  2021-06-06           0
#
#          company role_company  donation_frecuency  suscription_status  \
# 0           Nike          CTO                   1                   1
# 1     Particular   Particular                   0                   0
# 2     Particular   Particular                   0                   0
# 3       Jonhsons     Employee                   0                   1
# 4     The Oberoi     Employee                   1                   1
# ...          ...          ...                 ...                 ...
# 3929  Particular   Particular                   1                   1
# 3930  Particular   Particular                   1                   1
# 3931  Particular   Particular                   1                   1
# 3932  Particular   Particular                   1                   1
# 3933  Particular   Particular                   1                   1
#
#       donation_type   amount  method_pay donation_date  donation_month
# 0                 4     0.00           1    2021-11-14              11
# 1                 1  1355.38           3    2022-05-01               5
# 2                 1  8132.27           3    2014-10-18              10
# 3                 2     0.00           2    2018-06-11               6
# 4                 2     0.00           2    2024-01-30               1
# ...             ...      ...         ...           ...             ...
# 3929              1  3162.55           1    2022-09-06               9
# 3930              1  3162.55           1    2022-10-06              10
# 3931              1  3162.55           1    2022-11-06              11
# 3932              1  3162.55           1    2022-12-06              12
# 3933              1  3162.55           1    2023-01-06               1
#
# [3934 rows x 13 columns]

# %% [markdown]
# #### VISUALIZACIÓN. ANÁLISIS UNI Y BIVARIANTE.

# %%
particular_df = mp_donantes[mp_donantes['is_partner'] == 0]

plt.figure(figsize=(10, 6))
sns.distplot(particular_df['amount'], rug=True)

plt.xlabel('Amount')
plt.ylabel('Densidad')
plt.title('Distribución del monto de donación para particulares')

plt.show()
# Out:
# C:\Users\feder\AppData\Local\Temp\ipykernel_54324\647792063.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(particular_df['amount'], rug=True)

# %% [markdown]
# Como se puede apreciar el monto de las donaciones de particulares gira mayormente entre ₹1000 y ₹1500.

# %%
partner_counts = mp_donantes_numerico['is_partner'].value_counts()

total_donantes = partner_counts.sum()
percentages = (partner_counts / total_donantes) * 100

plt.figure(figsize=(8, 6))
bars = partner_counts.plot(kind='bar', color=['darkviolet', 'orange'])

plt.title('Frecuencia de donación en cuanto a tipo de donante')
plt.xlabel('is_partner')
plt.ylabel('Frecuencia')
plt.xticks(ticks=[0, 1], labels=['Individual', 'Empresa'])

for i, count in enumerate(partner_counts):
    plt.text(i, count + 1, f'{count} ({percentages[i]:.2f}%)', ha='center', va='bottom')

plt.show()

# %% [markdown]
# Como se vió anteriormente en los datos estadísticos, la mayor cantidad de donaciones son efectuadas por individuos.
#
# Vale aclarar que, los individuos solo realizan donaciones en efectivo, mientras que las empresas tienen cuatro tipos de donaciones, inlcuyendo especies además de efectivo.
#
# Si nos centramos únicamente en donaciones en efectivo se ve en el siguiente gráfico que la proporción es aún mayor.

# %%
efectivo_donantes = mp_donantes_numerico[mp_donantes_numerico['donation_type'] == 1]

efectivo_partner_counts = efectivo_donantes['is_partner'].value_counts()

total_efectivo_donantes = efectivo_partner_counts.sum()

efectivo_percentages = (efectivo_partner_counts / total_efectivo_donantes) * 100

plt.figure(figsize=(8, 6))
bars = efectivo_partner_counts.plot(kind='bar', color=['darkviolet', 'orange'])

plt.title('Frecuencia de donación en efectivo por tipo de donante')
plt.xlabel('is_partner')
plt.ylabel('Frecuencia')
plt.xticks(ticks=[0, 1], labels=['Individual', 'Empresa'])

for i, count in enumerate(efectivo_partner_counts):
    plt.text(i, count + 1, f'{count} ({efectivo_percentages[i]:.2f}%)', ha='center', va='bottom')

plt.show()

# %%
frecuency_counts = mp_donantes_numerico['donation_frecuency'].value_counts()

plt.figure(figsize=(8, 6))
frecuency_counts.plot(kind='bar', color=['brown', 'blue'])
plt.title('Frecuencia de donation_frecuency')
plt.xlabel('donation_frecuency')
plt.ylabel('Frecuencia')
plt.xticks(ticks=[0, 1], labels=['No Mensual', 'Mensual'])
plt.show()

# %% [markdown]
# La mayoría de los donantes no realizan donaciones mensuales, esto puede ser un parámetro a la hora de evaluar el nivel de compromiso constante del donante para con la organización.

# %%
type_counts = mp_donantes['donation_type'].value_counts()

type_percentages = (type_counts / type_counts.sum()) * 100

plt.figure(figsize=(8, 8))
plt.pie(type_counts, labels=type_counts.index, autopct='%1.2f%%')

circle = plt.Circle((0, 0), 0.7, color='white')
plt.gca().add_artist(circle)

plt.title('Porcentaje de cada tipo de donación')
plt.show()

# %% [markdown]
# El tipo de donación "1" que corresponde a dinero es la que prima dobre el resto con aproximadamente un 91%.

# %%
df_empresas = mp_donantes_numerico[mp_donantes_numerico['is_partner'] == 1]

frecuencia_donacion = df_empresas['donation_type'].value_counts()

plt.figure(figsize=(8, 6))
frecuencia_donacion.plot(kind='bar', color='skyblue')
plt.title('Tipo de Donación de las Empresas')
plt.xlabel('Tipo de Donación')
plt.ylabel('Frecuencia')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# En el caso puntualmente de las empresas (donde a diferencia de los particulares tienen cuatro formas de donar y no sólo efectivo) el tipo de donación esta un poco mas equilibrado, pero igualmente se aprecia que sigue siendo dinero la forma que más eligen para efectuar la donación.

# %%
mp_donantes['donation_date'] = pd.to_datetime(mp_donantes['donation_date'])
mp_donantes['donation_month'] = mp_donantes['donation_date'].dt.month
frecuencia_mes = mp_donantes['donation_month'].value_counts().sort_index()

meses = [calendar.month_name[i] for i in range(1, 13)]

plt.figure(figsize=(10, 6))
frecuencia_mes.plot(kind='bar', color='gold')
plt.title('Frecuencia de Donaciones por Mes')
plt.xlabel('Mes')
plt.ylabel('Frecuencia')
plt.xticks(range(12), meses, rotation=30)
plt.show()

# %% [markdown]
# No existe una gran disparidad en cuanto a la época del año en la que se recibe mayor cantidad de donaciones, pero a priori se observa una leve mayoría tanto en los primeros como en los últimos meses del año.

# %%
# Filtrado del DataFrame para incluir solo las donaciones en efectivo realizadas por empresas
empresas_efectivo_df = mp_donantes[(mp_donantes['donation_type'] == 1) & (mp_donantes['role_company'].notna())]

metodo_pago_nombres = {1: 'Tarjeta', 2: 'Paypal', 3: 'Googlepay'}

empresas_efectivo_df['method_pay'] = empresas_efectivo_df['method_pay'].replace(metodo_pago_nombres)

# Calculo de la frecuencia de cada método de pago utilizado por las empresas para las donaciones en efectivo
metodo_pago_counts = empresas_efectivo_df['method_pay'].value_counts()

plt.figure(figsize=(8, 6))
metodo_pago_counts.plot(kind='bar', color='red')

plt.title('Método de pago para donaciones en efectivo por parte de las empresas')
plt.xlabel('Método de Pago')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\feder\AppData\Local\Temp\ipykernel_54324\26489295.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empresas_efectivo_df['method_pay'] = empresas_efectivo_df['method_pay'].replace(metodo_pago_nombres)

# %%
mp_empresas = mp_donantes[mp_donantes['is_partner'] == 1]

plt.figure(figsize=(10, 6))
mp_empresas.boxplot(column='amount', by='method_pay')
plt.title('Relación entre Método de Pago y Monto de Donación (Empresas)')
plt.xlabel('Método de Pago')
plt.ylabel('Monto de Donación')
plt.xticks([1, 2, 3], ['Tarjeta', 'Paypal', 'Googlepay'])
plt.show()

# %% [markdown]
# Cuando la donación es en efectivo, las empresas eligen pagar con tarjeta. Pero, cuando el monto de la donación asciende, el método de pago mayormente elegido por las empresas, ya sea por conveniencia, incentivos, disponibilidad de fondos, o el motivo que fuese, es Googlepay.

# %%
sns.heatmap(mp_donantes_numerico.corr(),  linewidths=2, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap de correlación entre variables', fontsize=16)
plt.show()

# %%
X = mp_donantes_numerico.drop(columns=['amount'])

# Calculo del VIF para cada variable
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

print(vif_data)
# Out:
#              Variable        VIF
# 0          is_partner   3.523197
# 1  donation_frecuency  27.816841
# 2  suscription_status  36.206973
# 3       donation_type   8.704218
# 4          method_pay   5.119585

# %% [markdown]
# Las variables 'donation_frequency y 'suscription_status' parecen estar muy correlacionadas, lo cual sugiere realizar técnica de regularización previo a la clusterización del modelo.
